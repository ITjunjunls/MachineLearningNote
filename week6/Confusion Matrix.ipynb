# %% [markdown]
# # 分离数据
# 1.将数据分为两部分：训练集和测试集
# 2.使用训练集数据进行模型训练
# 3.使用测试集数据进行预测，评估模型对新数据的预测表现

# %% [markdown]
# # 混淆矩阵 Confusion Matrix
# ## 使用准确率进行模型评估的局限性：无法真实反映模型针对各个分类的预测准确度
#   准确率无法反映细节信息：不能体现数据预测的实际分布情况和不能体现模型错误预测的类型
#   ![image.png](attachment:image.png)
#   例如这两种预测，无法区别
#
# ## 混淆矩阵，又称为误差矩阵，用于衡量分类算法的准确程度
#   ![image-2.png](attachment:image-2.png)
#   ![image-3.png](attachment:image-3.png)
