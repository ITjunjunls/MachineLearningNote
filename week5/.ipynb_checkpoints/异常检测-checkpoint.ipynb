# %% [markdown]
# 异常检测就是类似于产生了很多数据，分布比较集中，也有不集中的，出现了不集中的数据表示可能有问题，如何判断是否集中，这里需要计算密度

# %% [markdown]
# # 概率密度
# 概率密度函数是一个描述随机变量在某个确定的取值点附近的可能性的函数
# ![image.png](attachment:image.png)
# p(x)为概率密度函数
# 想要通过概率密度来寻找概率很小的一个点，用高斯分布

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 还有个高维度的，我没听懂...
